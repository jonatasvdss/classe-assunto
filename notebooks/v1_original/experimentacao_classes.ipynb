# %%
import sys
import os
import joblib
import pandas as pd
import polars as pl
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

sys.path.append(os.path.abspath('..'))

from src.train_models import transformar_dados_teste
from src.evaluate import avaliar_modelo

caminho = r'..\data\v1_original\processed\classes_recorrentes_processado.csv'
df = pl.read_csv(caminho)

# %%
caminho_vet_classe = r'..\models\vetorizador_tfidf_classe.joblib'

X_teste_classe, y_teste_classe = transformar_dados_teste(
    df,
    caminho_vetorizador=caminho_vet_classe,
    coluna_texto="texto_limpo",
    coluna_alvo="classe"
)

resultados_modelos_classe = []

def registrar_metricas_classe(nome_modelo, y_true, y_pred):
    acc = accuracy_score(y_true, y_pred)
    _, _, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted', zero_division=0)
    resultados_modelos_classe.append({
        "Modelo": nome_modelo,
        "Acurácia": round(acc, 4),
        "F1-Score": round(f1, 4)
    })

# %%
modelo_nb_classe = joblib.load(r'..\models\modelo_naive_bayes_classe.joblib')

y_pred_nb_classe = modelo_nb_classe.predict(X_teste_classe)

avaliar_modelo(modelo_nb_classe, X_teste_classe, y_teste_classe, "Naive Bayes Classe")
registrar_metricas_classe("Naive Bayes", y_teste_classe, y_pred_nb_classe)
# Out:
# ============================================================
# RELATÓRIO DE CLASSIFICAÇÃO - NAIVE BAYES CLASSE
# ============================================================
#                                                                                                                                                                                                                                           precision    recall  f1-score   support
#
#                                                                                                                                                                                                            Agravo de Instrumento ( CPC )       0.59      0.82      0.69       400
#                                                                                                                                                                                                                   Carta Precatória Cível       0.83      0.80      0.82       800
#                                                                                                                                                                                                                          Execução Fiscal       0.98      0.98      0.98       400
#                                                                                                                                                                                                Execução de Título Extrajudicial ( L.E. )       0.50      0.89      0.64       400
#                                                                                                                                          PROCEDIMENTOS PRÉ-PROCESSUAIS DE RESOLUÇÃO CONSENSUAL DE CONFLITOS -> Reclamação Pré-processual       0.75      0.78      0.77       400
#                                                                                                                                                                                 PROCESSO CRIMINAL -> Cartas -> Carta Precatória Criminal       0.85      0.91      0.88       400
#                                                                                                                                                                      PROCESSO CRIMINAL -> Medidas Garantidoras -> Habeas Corpus Criminal       0.84      0.86      0.85       400
#                                                                                                                                         PROCESSO CRIMINAL -> Medidas Garantidoras -> Liberdade -> Liberdade Provisória com ou sem fiança       0.89      0.85      0.87       400
#                                                                                                                                                                                       PROCESSO CRIMINAL -> Recursos -> Apelação Criminal       0.97      0.99      0.98       400
#                                                                                                                                              PROCESSO CÍVEL E DO TRABALHO -> Outros Procedimentos -> Atos e expedientes -> Petição Cível       0.33      0.10      0.16       200
#                                                                                          PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimento do Juizado Especial da Fazenda Pública       0.55      0.52      0.53       200
#                                                   PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Especiais de Jurisdição Contenciosa -> Inventário       0.76      0.92      0.83       400
#                                                    PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Especiais de Jurisdição Contenciosa -> Monitória       0.81      0.92      0.86       400
#                                           PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Especiais de Jurisdição Voluntária -> Interdição/Curatela       0.88      0.91      0.90       400
#      PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Regidos por Outros Códigos, Leis Esparsas e Regimentos -> Alimentos - Lei Especial Nº 5.478/68       0.78      0.81      0.80       400
#             PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Regidos por Outros Códigos, Leis Esparsas e Regimentos -> Alvará Judicial - Lei 6858/80       0.92      0.83      0.87       400
# PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Regidos por Outros Códigos, Leis Esparsas e Regimentos -> Busca e Apreensão em Alienação Fiduciária       0.81      0.94      0.88       200
#                PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Regidos por Outros Códigos, Leis Esparsas e Regimentos -> Mandado de Segurança Cível       0.76      0.85      0.80       400
#                                                                          PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Cumprimento de Sentença/Decisão -> Cumprimento de Sentença contra a Fazenda Pública       0.61      0.69      0.65       400
#                                                                 PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Cumprimento de Sentença/Decisão -> Cumprimento de Sentença de Obrigação de Prestar Alimentos       0.78      0.87      0.82       400
#                                                                                                   PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Cumprimento de Sentença/Decisão -> Cumprimento de sentença       0.65      0.34      0.44       400
#                                                                                                                                                  PROCESSO CÍVEL E DO TRABALHO -> Processo de Execução -> Embargos -> Embargos à Execução       0.83      0.85      0.84       400
#                                                                                                             PROCESSO CÍVEL E DO TRABALHO -> Processo de Execução -> Execução de Título Extrajudicial -> Execução de Título Extrajudicial       1.00      0.01      0.02       200
#                                                                                                                                                             PROCESSO CÍVEL E DO TRABALHO -> Recursos -> Agravos -> Agravo de Instrumento       0.91      0.05      0.09       200
#                                                                                                          PROCESSO CÍVEL E DO TRABALHO -> Tutela Provisória de Urgência e Tutela Provisória de Evidência -> Tutela Antecipada Antecedente       0.64      0.49      0.55       400
#                                                                                                                                                                                                                       Procedimento Comum       0.70      0.56      0.62       800
#                                                                                                                                                                                                   Procedimento do Juizado Especial Cível       0.39      0.57      0.46       400
#
#                                                                                                                                                                                                                                 accuracy                           0.74     10600
#                                                                                                                                                                                                                                macro avg       0.75      0.71      0.69     10600
#                                                                                                                                                                                                                             weighted avg       0.76      0.74      0.72     10600
#
# Matriz de confusão salva em: c:\Users\jonat\OneDrive\Área de Trabalho\classe-assunto\imgs\matriz_confusao_naive_bayes_classe.png

# %%
modelo_rf_classe = joblib.load(r'..\models\modelo_random_forest_classe.joblib')

y_pred_rf_classe = modelo_rf_classe.predict(X_teste_classe)

avaliar_modelo(modelo_rf_classe, X_teste_classe, y_teste_classe, "Random Forest Classe")
registrar_metricas_classe("Random Forest", y_teste_classe, y_pred_rf_classe)
# Out:
# ============================================================
# RELATÓRIO DE CLASSIFICAÇÃO - RANDOM FOREST CLASSE
# ============================================================
#                                                                                                                                                                                                                                           precision    recall  f1-score   support
#
#                                                                                                                                                                                                            Agravo de Instrumento ( CPC )       0.71      0.94      0.81       400
#                                                                                                                                                                                                                   Carta Precatória Cível       0.91      0.92      0.91       800
#                                                                                                                                                                                                                          Execução Fiscal       0.99      0.99      0.99       400
#                                                                                                                                                                                                Execução de Título Extrajudicial ( L.E. )       0.72      0.92      0.81       400
#                                                                                                                                          PROCEDIMENTOS PRÉ-PROCESSUAIS DE RESOLUÇÃO CONSENSUAL DE CONFLITOS -> Reclamação Pré-processual       0.89      0.92      0.90       400
#                                                                                                                                                                                 PROCESSO CRIMINAL -> Cartas -> Carta Precatória Criminal       0.93      0.95      0.94       400
#                                                                                                                                                                      PROCESSO CRIMINAL -> Medidas Garantidoras -> Habeas Corpus Criminal       0.96      0.98      0.97       400
#                                                                                                                                         PROCESSO CRIMINAL -> Medidas Garantidoras -> Liberdade -> Liberdade Provisória com ou sem fiança       0.96      0.95      0.95       400
#                                                                                                                                                                                       PROCESSO CRIMINAL -> Recursos -> Apelação Criminal       1.00      0.99      0.99       400
#                                                                                                                                              PROCESSO CÍVEL E DO TRABALHO -> Outros Procedimentos -> Atos e expedientes -> Petição Cível       0.88      0.19      0.31       200
#                                                                                          PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimento do Juizado Especial da Fazenda Pública       0.75      0.79      0.77       200
#                                                   PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Especiais de Jurisdição Contenciosa -> Inventário       0.90      0.96      0.93       400
#                                                    PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Especiais de Jurisdição Contenciosa -> Monitória       0.95      0.97      0.96       400
#                                           PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Especiais de Jurisdição Voluntária -> Interdição/Curatela       0.98      0.97      0.98       400
#      PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Regidos por Outros Códigos, Leis Esparsas e Regimentos -> Alimentos - Lei Especial Nº 5.478/68       0.89      0.90      0.89       400
#             PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Regidos por Outros Códigos, Leis Esparsas e Regimentos -> Alvará Judicial - Lei 6858/80       0.93      0.94      0.93       400
# PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Regidos por Outros Códigos, Leis Esparsas e Regimentos -> Busca e Apreensão em Alienação Fiduciária       0.91      0.97      0.94       200
#                PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Regidos por Outros Códigos, Leis Esparsas e Regimentos -> Mandado de Segurança Cível       0.93      0.97      0.95       400
#                                                                          PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Cumprimento de Sentença/Decisão -> Cumprimento de Sentença contra a Fazenda Pública       0.86      0.80      0.83       400
#                                                                 PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Cumprimento de Sentença/Decisão -> Cumprimento de Sentença de Obrigação de Prestar Alimentos       0.87      0.88      0.87       400
#                                                                                                   PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Cumprimento de Sentença/Decisão -> Cumprimento de sentença       0.83      0.72      0.77       400
#                                                                                                                                                  PROCESSO CÍVEL E DO TRABALHO -> Processo de Execução -> Embargos -> Embargos à Execução       0.94      0.92      0.93       400
#                                                                                                             PROCESSO CÍVEL E DO TRABALHO -> Processo de Execução -> Execução de Título Extrajudicial -> Execução de Título Extrajudicial       0.87      0.47      0.61       200
#                                                                                                                                                             PROCESSO CÍVEL E DO TRABALHO -> Recursos -> Agravos -> Agravo de Instrumento       0.86      0.28      0.43       200
#                                                                                                          PROCESSO CÍVEL E DO TRABALHO -> Tutela Provisória de Urgência e Tutela Provisória de Evidência -> Tutela Antecipada Antecedente       0.67      0.73      0.70       400
#                                                                                                                                                                                                                       Procedimento Comum       0.77      0.79      0.78       800
#                                                                                                                                                                                                   Procedimento do Juizado Especial Cível       0.66      0.74      0.70       400
#
#                                                                                                                                                                                                                                 accuracy                           0.86     10600
#                                                                                                                                                                                                                                macro avg       0.87      0.84      0.84     10600
#                                                                                                                                                                                                                             weighted avg       0.87      0.86      0.86     10600
#
# Matriz de confusão salva em: c:\Users\jonat\OneDrive\Área de Trabalho\classe-assunto\imgs\matriz_confusao_random_forest_classe.png

# %%
modelo_lr_classe = joblib.load(r'..\models\modelo_regressao_logistica_classe.joblib')

y_pred_lr_classe = modelo_lr_classe.predict(X_teste_classe)

avaliar_modelo(modelo_lr_classe, X_teste_classe, y_teste_classe, "Regressao Logistica Classe")
registrar_metricas_classe("Regressão Logística", y_teste_classe, y_pred_lr_classe)
# Out:
# ============================================================
# RELATÓRIO DE CLASSIFICAÇÃO - REGRESSAO LOGISTICA CLASSE
# ============================================================
#                                                                                                                                                                                                                                           precision    recall  f1-score   support
#
#                                                                                                                                                                                                            Agravo de Instrumento ( CPC )       0.80      0.83      0.82       400
#                                                                                                                                                                                                                   Carta Precatória Cível       0.93      0.86      0.90       800
#                                                                                                                                                                                                                          Execução Fiscal       0.99      0.99      0.99       400
#                                                                                                                                                                                                Execução de Título Extrajudicial ( L.E. )       0.80      0.81      0.81       400
#                                                                                                                                          PROCEDIMENTOS PRÉ-PROCESSUAIS DE RESOLUÇÃO CONSENSUAL DE CONFLITOS -> Reclamação Pré-processual       0.80      0.88      0.84       400
#                                                                                                                                                                                 PROCESSO CRIMINAL -> Cartas -> Carta Precatória Criminal       0.89      0.97      0.93       400
#                                                                                                                                                                      PROCESSO CRIMINAL -> Medidas Garantidoras -> Habeas Corpus Criminal       0.91      0.95      0.93       400
#                                                                                                                                         PROCESSO CRIMINAL -> Medidas Garantidoras -> Liberdade -> Liberdade Provisória com ou sem fiança       0.95      0.90      0.93       400
#                                                                                                                                                                                       PROCESSO CRIMINAL -> Recursos -> Apelação Criminal       0.99      0.99      0.99       400
#                                                                                                                                              PROCESSO CÍVEL E DO TRABALHO -> Outros Procedimentos -> Atos e expedientes -> Petição Cível       0.31      0.42      0.36       200
#                                                                                          PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimento do Juizado Especial da Fazenda Pública       0.58      0.87      0.69       200
#                                                   PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Especiais de Jurisdição Contenciosa -> Inventário       0.92      0.94      0.93       400
#                                                    PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Especiais de Jurisdição Contenciosa -> Monitória       0.89      0.95      0.92       400
#                                           PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Especiais de Jurisdição Voluntária -> Interdição/Curatela       0.98      0.93      0.95       400
#      PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Regidos por Outros Códigos, Leis Esparsas e Regimentos -> Alimentos - Lei Especial Nº 5.478/68       0.86      0.86      0.86       400
#             PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Regidos por Outros Códigos, Leis Esparsas e Regimentos -> Alvará Judicial - Lei 6858/80       0.93      0.91      0.92       400
# PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Regidos por Outros Códigos, Leis Esparsas e Regimentos -> Busca e Apreensão em Alienação Fiduciária       0.91      0.96      0.94       200
#                PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Conhecimento -> Procedimentos Especiais -> Procedimentos Regidos por Outros Códigos, Leis Esparsas e Regimentos -> Mandado de Segurança Cível       0.91      0.91      0.91       400
#                                                                          PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Cumprimento de Sentença/Decisão -> Cumprimento de Sentença contra a Fazenda Pública       0.80      0.73      0.76       400
#                                                                 PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Cumprimento de Sentença/Decisão -> Cumprimento de Sentença de Obrigação de Prestar Alimentos       0.81      0.83      0.82       400
#                                                                                                   PROCESSO CÍVEL E DO TRABALHO -> Processo de Conhecimento -> Procedimento de Cumprimento de Sentença/Decisão -> Cumprimento de sentença       0.75      0.69      0.72       400
#                                                                                                                                                  PROCESSO CÍVEL E DO TRABALHO -> Processo de Execução -> Embargos -> Embargos à Execução       0.96      0.87      0.91       400
#                                                                                                             PROCESSO CÍVEL E DO TRABALHO -> Processo de Execução -> Execução de Título Extrajudicial -> Execução de Título Extrajudicial       0.61      0.69      0.64       200
#                                                                                                                                                             PROCESSO CÍVEL E DO TRABALHO -> Recursos -> Agravos -> Agravo de Instrumento       0.63      0.66      0.65       200
#                                                                                                          PROCESSO CÍVEL E DO TRABALHO -> Tutela Provisória de Urgência e Tutela Provisória de Evidência -> Tutela Antecipada Antecedente       0.65      0.70      0.67       400
#                                                                                                                                                                                                                       Procedimento Comum       0.84      0.60      0.70       800
#                                                                                                                                                                                                   Procedimento do Juizado Especial Cível       0.58      0.64      0.61       400
#
#                                                                                                                                                                                                                                 accuracy                           0.83     10600
#                                                                                                                                                                                                                                macro avg       0.82      0.83      0.82     10600
#                                                                                                                                                                                                                             weighted avg       0.84      0.83      0.83     10600
#
# Matriz de confusão salva em: c:\Users\jonat\OneDrive\Área de Trabalho\classe-assunto\imgs\matriz_confusao_regressao_logistica_classe.png

# %%
le_classe = joblib.load(r'..\models\label_encoder_classe.joblib')
y_teste_classe_enc = le_classe.transform(y_teste_classe)

# %%
modelo_lgbm_classe = joblib.load(r'..\models\modelo_lightgbm_classe.joblib')
y_pred_lgbm_classe_enc = modelo_lgbm_classe.predict(X_teste_classe)
y_pred_lgbm_classe = le_classe.inverse_transform(y_pred_lgbm_classe_enc)

avaliar_modelo(modelo_lgbm_classe, X_teste_classe, y_teste_classe_enc, "LightGBM Classe")
registrar_metricas_classe("LightGBM", y_teste_classe, y_pred_lgbm_classe)
# Out:
# ============================================================
# RELATÓRIO DE CLASSIFICAÇÃO - LIGHTGBM CLASSE
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.89       400
#            1       0.95      0.93      0.94       800
#            2       1.00      0.98      0.99       400
#            3       0.82      0.89      0.85       400
#            4       0.91      0.91      0.91       400
#            5       0.93      0.97      0.95       400
#            6       0.97      0.98      0.98       400
#            7       0.97      0.95      0.96       400
#            8       1.00      0.99      0.99       400
#            9       0.48      0.29      0.37       200
#           10       0.75      0.84      0.79       200
#           11       0.96      0.96      0.96       400
#           12       0.96      0.97      0.96       400
#           13       0.97      0.98      0.98       400
#           14       0.90      0.90      0.90       400
#           15       0.95      0.95      0.95       400
#           16       0.94      0.99      0.96       200
#           17       0.97      0.96      0.97       400
#           18       0.84      0.80      0.82       400
#           19       0.88      0.88      0.88       400
#           20       0.79      0.77      0.78       400
#           21       0.97      0.91      0.94       400
#           22       0.73      0.68      0.70       200
#           23       0.80      0.72      0.76       200
#           24       0.68      0.77      0.72       400
#           25       0.79      0.80      0.79       800
#           26       0.68      0.73      0.70       400
#
#     accuracy                           0.88     10600
#    macro avg       0.87      0.87      0.87     10600
# weighted avg       0.88      0.88      0.88     10600
#
# Matriz de confusão salva em: c:\Users\jonat\OneDrive\Área de Trabalho\classe-assunto\imgs\matriz_confusao_lightgbm_classe.png

# %%
modelo_xgb_classe = joblib.load(r'..\models\modelo_xgboost_classe.joblib')
y_pred_xgb_classe_enc = modelo_xgb_classe.predict(X_teste_classe)
y_pred_xgb_classe = le_classe.inverse_transform(y_pred_xgb_classe_enc)

avaliar_modelo(modelo_xgb_classe, X_teste_classe, y_teste_classe_enc, "XGBoost Classe")
registrar_metricas_classe("XGBoost", y_teste_classe, y_pred_xgb_classe)
# Out:
# ============================================================
# RELATÓRIO DE CLASSIFICAÇÃO - XGBOOST CLASSE
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85       400
#            1       0.93      0.93      0.93       800
#            2       1.00      0.99      0.99       400
#            3       0.80      0.85      0.83       400
#            4       0.90      0.92      0.91       400
#            5       0.94      0.96      0.95       400
#            6       0.97      0.98      0.98       400
#            7       0.97      0.95      0.96       400
#            8       0.99      0.99      0.99       400
#            9       0.53      0.28      0.36       200
#           10       0.77      0.79      0.78       200
#           11       0.95      0.96      0.96       400
#           12       0.96      0.97      0.96       400
#           13       0.97      0.98      0.97       400
#           14       0.89      0.91      0.90       400
#           15       0.95      0.96      0.95       400
#           16       0.91      0.98      0.94       200
#           17       0.97      0.97      0.97       400
#           18       0.85      0.81      0.83       400
#           19       0.88      0.85      0.86       400
#           20       0.80      0.74      0.77       400
#           21       0.96      0.92      0.93       400
#           22       0.71      0.67      0.69       200
#           23       0.74      0.64      0.69       200
#           24       0.69      0.76      0.72       400
#           25       0.76      0.81      0.79       800
#           26       0.70      0.71      0.70       400
#
#     accuracy                           0.88     10600
#    macro avg       0.86      0.86      0.86     10600
# weighted avg       0.87      0.88      0.87     10600
#
# Matriz de confusão salva em: c:\Users\jonat\OneDrive\Área de Trabalho\classe-assunto\imgs\matriz_confusao_xgboost_classe.png

# %%
df_comparacao_classe = pd.DataFrame(resultados_modelos_classe)
display(df_comparacao_classe.sort_values(by="F1-Score", ascending=False))
# Out:
#                 Modelo  Acurácia  F1-Score
# 3             LightGBM    0.8820    0.8805
# 4              XGBoost    0.8761    0.8738
# 1        Random Forest    0.8649    0.8579
# 2  Regressão Logística    0.8308    0.8324
# 0          Naive Bayes    0.7419    0.7243
