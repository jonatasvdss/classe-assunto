# %%
import sys
import os
import joblib
import pandas as pd
import polars as pl
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

sys.path.append(os.path.abspath('../..'))

from src.train_models import transformar_dados_teste
from src.evaluate import avaliar_modelo

caminho = r'..\..\data\v2_ftp\processed\assuntos_recorrentes_processado.csv'
df = pl.read_csv(caminho)

# %%
caminho_vet_assunto = r'..\..\models\v2_ftp\vectors\vetorizador_tfidf_assunto.joblib'

X_teste_assunto, y_teste_assunto = transformar_dados_teste(
    df,
    caminho_vetorizador=caminho_vet_assunto,
    coluna_texto="texto_limpo",
    coluna_alvo="assunto"
)

resultados_modelos_assunto = []

def registrar_metricas_assunto(nome_modelo, y_true, y_pred):
    acc = accuracy_score(y_true, y_pred)
    _, _, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted', zero_division=0)
    resultados_modelos_assunto.append({
        "Modelo": nome_modelo,
        "Acurácia": round(acc, 4),
        "F1-Score": round(f1, 4)
    })

# %%
modelo_nb_assunto = joblib.load(r'..\..\models\v2_ftp\modelo_naive_bayes_assunto.joblib')

y_pred_nb_assunto = modelo_nb_assunto.predict(X_teste_assunto)

avaliar_modelo(modelo_nb_assunto, X_teste_assunto, y_teste_assunto, "Naive Bayes Assunto")
registrar_metricas_assunto("Naive Bayes", y_teste_assunto, y_pred_nb_assunto)
# Out:
# ============================================================
# RELATÓRIO DE CLASSIFICAÇÃO - NAIVE BAYES ASSUNTO
# ============================================================
#                                                     precision    recall  f1-score   support
#
#                               Acidente de Trânsito       0.71      0.90      0.80       400
#                          Adicional de Horas Extras       0.63      0.72      0.68       400
#                               Alienação Fiduciária       0.96      0.85      0.90       400
#                                          Alimentos       0.78      0.93      0.85       400
#                   Aposentadoria Rural (Art. 48/51)       0.61      0.51      0.56       400
#          Aposentadoria por Incapacidade Permanente       0.92      0.93      0.92       400
#                                      Atraso de vôo       0.58      0.87      0.69       400
#                                Cancelamento de vôo       0.58      0.46      0.51       400
#                                  Cartão de Crédito       0.53      0.70      0.61       400
#                                             Cheque       0.79      0.79      0.79       400
#                 Cobrança de Aluguéis - Sem despejo       0.69      0.71      0.70       400
#                 Competência dos Juizados Especiais       0.37      0.20      0.26       400
#                                     Compra e Venda       0.42      0.44      0.43       400
#                                Contratos Bancários       0.56      0.32      0.40       400
#                                 Correção Monetária       0.74      0.46      0.57       400
#                         Cédula de Crédito Bancário       0.77      0.76      0.76       400
#                                Descontos Indevidos       0.89      0.87      0.88       400
#                              Despesas Condominiais       0.84      0.93      0.88       400
#                                  Direito de Imagem       0.37      0.52      0.43       400
#                                          Duplicata       0.73      0.57      0.64       400
#                              Empréstimo consignado       0.70      0.58      0.64       400
#                                    Fazenda Pública       0.97      0.87      0.92       400
#                               Finalidade - CITACAO       0.57      0.41      0.48       237
#                        Finalidade - EXPEDIR ALVARA       0.86      0.81      0.83       400
#                                            Fixação       0.84      0.81      0.82       400
#                                       Horas Extras       0.71      0.68      0.70       400
#                                    ICMS/Importação       0.95      0.40      0.56        98
#         IPTU/ Imposto Predial e Territorial Urbano       0.63      0.44      0.52       242
#                        ISS/ Imposto sobre Serviços       0.95      0.15      0.26       137
#     Inclusão Indevida em Cadastro de Inadimplentes       0.65      0.68      0.67       200
#                      Indenização por Dano Material       0.00      0.00      0.00       200
#                              Inventário e Partilha       0.66      0.83      0.74       400
#                            Multas e demais Sanções       0.46      0.85      0.59       400
#                                           Nomeação       0.91      0.98      0.95       400
#                                   Nota Promissória       0.49      0.96      0.65       600
#                     Obrigação de Fazer / Não Fazer       0.44      0.35      0.39       600
#                                          Pagamento       0.52      0.20      0.29       400
#                                     Perdas e Danos       0.91      0.25      0.40       400
#                             Pessoa com Deficiência       0.93      0.95      0.94       400
#                                      Piso Salarial       0.88      0.70      0.78       400
#                              Prestação de Serviços       0.55      0.64      0.59       400
# Progressão Funcional com Interstício de Doze Meses       0.76      0.95      0.84       400
#                              Repetição do Indébito       0.47      0.61      0.53       400
#                               Rescisão / Resolução       0.81      0.40      0.54       400
#       Rescisão do contrato e devolução do dinheiro       0.43      0.61      0.50       400
#                                 Rural (Art. 48/51)       0.59      0.68      0.63       400
#                 Tráfico de Drogas e Condutas Afins       0.88      0.95      0.91       400
#
#                                           accuracy                           0.66     17914
#                                          macro avg       0.68      0.64      0.64     17914
#                                       weighted avg       0.68      0.66      0.65     17914
#
# Matriz de confusão salva em: c:\Users\jonat\OneDrive\Área de Trabalho\classe-assunto\imgs\v1_original\matriz_confusao_naive_bayes_assunto.png

# %%
modelo_rf_assunto = joblib.load(r'..\..\models\v2_ftp\modelo_random_forest_assunto.joblib')

y_pred_rf_assunto = modelo_rf_assunto.predict(X_teste_assunto)

avaliar_modelo(modelo_rf_assunto, X_teste_assunto, y_teste_assunto, "Random Forest Assunto")
registrar_metricas_assunto("Random Forest", y_teste_assunto, y_pred_rf_assunto)
# Out:
# ============================================================
# RELATÓRIO DE CLASSIFICAÇÃO - RANDOM FOREST ASSUNTO
# ============================================================
#                                                     precision    recall  f1-score   support
#
#                               Acidente de Trânsito       0.73      0.94      0.82       400
#                          Adicional de Horas Extras       0.80      0.83      0.82       400
#                               Alienação Fiduciária       0.91      0.94      0.93       400
#                                          Alimentos       0.81      0.96      0.88       400
#                   Aposentadoria Rural (Art. 48/51)       0.71      0.73      0.72       400
#          Aposentadoria por Incapacidade Permanente       0.93      0.94      0.94       400
#                                      Atraso de vôo       0.69      0.82      0.75       400
#                                Cancelamento de vôo       0.63      0.70      0.67       400
#                                  Cartão de Crédito       0.73      0.79      0.76       400
#                                             Cheque       0.77      0.92      0.84       400
#                 Cobrança de Aluguéis - Sem despejo       0.73      0.79      0.76       400
#                 Competência dos Juizados Especiais       0.78      0.46      0.58       400
#                                     Compra e Venda       0.57      0.58      0.57       400
#                                Contratos Bancários       0.80      0.55      0.65       400
#                                 Correção Monetária       0.91      0.74      0.82       400
#                         Cédula de Crédito Bancário       0.76      0.86      0.81       400
#                                Descontos Indevidos       0.96      0.95      0.96       400
#                              Despesas Condominiais       0.93      0.97      0.95       400
#                                  Direito de Imagem       0.51      0.61      0.56       400
#                                          Duplicata       0.79      0.88      0.83       400
#                              Empréstimo consignado       0.68      0.84      0.75       400
#                                    Fazenda Pública       0.98      0.93      0.95       400
#                               Finalidade - CITACAO       0.83      0.45      0.58       237
#                        Finalidade - EXPEDIR ALVARA       0.87      0.86      0.86       400
#                                            Fixação       0.83      0.81      0.82       400
#                                       Horas Extras       0.81      0.76      0.78       400
#                                    ICMS/Importação       0.78      0.77      0.77        98
#         IPTU/ Imposto Predial e Territorial Urbano       0.75      0.83      0.79       242
#                        ISS/ Imposto sobre Serviços       0.81      0.58      0.67       137
#     Inclusão Indevida em Cadastro de Inadimplentes       0.68      0.75      0.71       200
#                      Indenização por Dano Material       0.44      0.15      0.23       200
#                              Inventário e Partilha       0.78      0.90      0.83       400
#                            Multas e demais Sanções       0.73      0.86      0.79       400
#                                           Nomeação       0.93      0.97      0.95       400
#                                   Nota Promissória       0.83      0.96      0.89       600
#                     Obrigação de Fazer / Não Fazer       0.67      0.50      0.58       600
#                                          Pagamento       0.67      0.49      0.56       400
#                                     Perdas e Danos       0.80      0.41      0.54       400
#                             Pessoa com Deficiência       0.92      0.97      0.95       400
#                                      Piso Salarial       0.94      0.96      0.95       400
#                              Prestação de Serviços       0.66      0.77      0.71       400
# Progressão Funcional com Interstício de Doze Meses       0.89      0.97      0.93       400
#                              Repetição do Indébito       0.66      0.61      0.63       400
#                               Rescisão / Resolução       0.78      0.56      0.65       400
#       Rescisão do contrato e devolução do dinheiro       0.51      0.63      0.57       400
#                                 Rural (Art. 48/51)       0.73      0.71      0.72       400
#                 Tráfico de Drogas e Condutas Afins       0.94      0.97      0.96       400
#
#                                           accuracy                           0.78     17914
#                                          macro avg       0.77      0.76      0.76     17914
#                                       weighted avg       0.78      0.78      0.77     17914
#
# Matriz de confusão salva em: c:\Users\jonat\OneDrive\Área de Trabalho\classe-assunto\imgs\v1_original\matriz_confusao_random_forest_assunto.png

# %%
modelo_lr_assunto = joblib.load(r'..\..\models\v2_ftp\modelo_regressao_logistica_assunto.joblib')

y_pred_lr_assunto = modelo_lr_assunto.predict(X_teste_assunto)

avaliar_modelo(modelo_lr_assunto, X_teste_assunto, y_teste_assunto, "Regressao Logistica Assunto")
registrar_metricas_assunto("Regressão Logística", y_teste_assunto, y_pred_lr_assunto)
# Out:
# ============================================================
# RELATÓRIO DE CLASSIFICAÇÃO - REGRESSAO LOGISTICA ASSUNTO
# ============================================================
#                                                     precision    recall  f1-score   support
#
#                               Acidente de Trânsito       0.83      0.90      0.86       400
#                          Adicional de Horas Extras       0.80      0.75      0.78       400
#                               Alienação Fiduciária       0.94      0.94      0.94       400
#                                          Alimentos       0.83      0.93      0.88       400
#                   Aposentadoria Rural (Art. 48/51)       0.72      0.70      0.71       400
#          Aposentadoria por Incapacidade Permanente       0.93      0.94      0.94       400
#                                      Atraso de vôo       0.73      0.78      0.75       400
#                                Cancelamento de vôo       0.66      0.71      0.69       400
#                                  Cartão de Crédito       0.69      0.78      0.73       400
#                                             Cheque       0.79      0.88      0.83       400
#                 Cobrança de Aluguéis - Sem despejo       0.81      0.72      0.76       400
#                 Competência dos Juizados Especiais       0.54      0.43      0.48       400
#                                     Compra e Venda       0.52      0.55      0.53       400
#                                Contratos Bancários       0.66      0.57      0.61       400
#                                 Correção Monetária       0.79      0.70      0.74       400
#                         Cédula de Crédito Bancário       0.77      0.86      0.81       400
#                                Descontos Indevidos       0.95      0.95      0.95       400
#                              Despesas Condominiais       0.94      0.96      0.95       400
#                                  Direito de Imagem       0.57      0.59      0.58       400
#                                          Duplicata       0.81      0.81      0.81       400
#                              Empréstimo consignado       0.73      0.75      0.74       400
#                                    Fazenda Pública       0.94      0.93      0.93       400
#                               Finalidade - CITACAO       0.68      0.62      0.65       237
#                        Finalidade - EXPEDIR ALVARA       0.89      0.89      0.89       400
#                                            Fixação       0.90      0.80      0.85       400
#                                       Horas Extras       0.77      0.79      0.78       400
#                                    ICMS/Importação       0.64      0.92      0.76        98
#         IPTU/ Imposto Predial e Territorial Urbano       0.72      0.85      0.78       242
#                        ISS/ Imposto sobre Serviços       0.65      0.61      0.63       137
#     Inclusão Indevida em Cadastro de Inadimplentes       0.68      0.77      0.72       200
#                      Indenização por Dano Material       0.26      0.39      0.31       200
#                              Inventário e Partilha       0.82      0.88      0.85       400
#                            Multas e demais Sanções       0.81      0.81      0.81       400
#                                           Nomeação       0.97      0.97      0.97       400
#                                   Nota Promissória       0.85      0.94      0.89       600
#                     Obrigação de Fazer / Não Fazer       0.69      0.52      0.59       600
#                                          Pagamento       0.53      0.49      0.51       400
#                                     Perdas e Danos       0.61      0.42      0.50       400
#                             Pessoa com Deficiência       0.96      0.96      0.96       400
#                                      Piso Salarial       0.93      0.94      0.93       400
#                              Prestação de Serviços       0.66      0.74      0.70       400
# Progressão Funcional com Interstício de Doze Meses       0.89      0.97      0.93       400
#                              Repetição do Indébito       0.67      0.62      0.65       400
#                               Rescisão / Resolução       0.72      0.60      0.65       400
#       Rescisão do contrato e devolução do dinheiro       0.58      0.59      0.59       400
#                                 Rural (Art. 48/51)       0.72      0.74      0.73       400
#                 Tráfico de Drogas e Condutas Afins       0.97      0.97      0.97       400
#
#                                           accuracy                           0.77     17914
#                                          macro avg       0.76      0.76      0.76     17914
#                                       weighted avg       0.77      0.77      0.77     17914
#
# Matriz de confusão salva em: c:\Users\jonat\OneDrive\Área de Trabalho\classe-assunto\imgs\v1_original\matriz_confusao_regressao_logistica_assunto.png

# %%
modelo_svc_assunto = joblib.load(r'..\..\models\v2_ftp\modelo_linearsvc_assunto.joblib')

y_pred_svc_assunto = modelo_svc_assunto.predict(X_teste_assunto)

avaliar_modelo(modelo_svc_assunto, X_teste_assunto, y_teste_assunto, "LinearSVC Assunto")
registrar_metricas_assunto("LinearSVC", y_teste_assunto, y_pred_svc_assunto)
# Out:
# ============================================================
# RELATÓRIO DE CLASSIFICAÇÃO - LINEARSVC ASSUNTO
# ============================================================
#                                                     precision    recall  f1-score   support
#
#                               Acidente de Trânsito       0.80      0.91      0.85       400
#                          Adicional de Horas Extras       0.80      0.77      0.79       400
#                               Alienação Fiduciária       0.91      0.94      0.93       400
#                                          Alimentos       0.82      0.94      0.88       400
#                   Aposentadoria Rural (Art. 48/51)       0.73      0.71      0.72       400
#          Aposentadoria por Incapacidade Permanente       0.93      0.94      0.93       400
#                                      Atraso de vôo       0.72      0.76      0.74       400
#                                Cancelamento de vôo       0.63      0.73      0.68       400
#                                  Cartão de Crédito       0.71      0.79      0.75       400
#                                             Cheque       0.77      0.89      0.82       400
#                 Cobrança de Aluguéis - Sem despejo       0.77      0.75      0.76       400
#                 Competência dos Juizados Especiais       0.62      0.47      0.54       400
#                                     Compra e Venda       0.53      0.55      0.54       400
#                                Contratos Bancários       0.69      0.60      0.64       400
#                                 Correção Monetária       0.82      0.77      0.79       400
#                         Cédula de Crédito Bancário       0.76      0.86      0.81       400
#                                Descontos Indevidos       0.95      0.96      0.96       400
#                              Despesas Condominiais       0.95      0.96      0.96       400
#                                  Direito de Imagem       0.60      0.57      0.59       400
#                                          Duplicata       0.81      0.83      0.82       400
#                              Empréstimo consignado       0.76      0.78      0.77       400
#                                    Fazenda Pública       0.95      0.94      0.94       400
#                               Finalidade - CITACAO       0.74      0.62      0.68       237
#                        Finalidade - EXPEDIR ALVARA       0.89      0.91      0.90       400
#                                            Fixação       0.90      0.81      0.85       400
#                                       Horas Extras       0.78      0.79      0.78       400
#                                    ICMS/Importação       0.78      0.88      0.83        98
#         IPTU/ Imposto Predial e Territorial Urbano       0.73      0.86      0.79       242
#                        ISS/ Imposto sobre Serviços       0.67      0.61      0.64       137
#     Inclusão Indevida em Cadastro de Inadimplentes       0.71      0.74      0.73       200
#                      Indenização por Dano Material       0.28      0.30      0.29       200
#                              Inventário e Partilha       0.83      0.87      0.85       400
#                            Multas e demais Sanções       0.80      0.83      0.81       400
#                                           Nomeação       0.98      0.97      0.98       400
#                                   Nota Promissória       0.84      0.95      0.89       600
#                     Obrigação de Fazer / Não Fazer       0.70      0.53      0.60       600
#                                          Pagamento       0.57      0.47      0.51       400
#                                     Perdas e Danos       0.62      0.44      0.51       400
#                             Pessoa com Deficiência       0.95      0.96      0.95       400
#                                      Piso Salarial       0.93      0.96      0.94       400
#                              Prestação de Serviços       0.68      0.73      0.71       400
# Progressão Funcional com Interstício de Doze Meses       0.92      0.98      0.95       400
#                              Repetição do Indébito       0.66      0.63      0.64       400
#                               Rescisão / Resolução       0.68      0.60      0.63       400
#       Rescisão do contrato e devolução do dinheiro       0.54      0.57      0.56       400
#                                 Rural (Art. 48/51)       0.72      0.73      0.73       400
#                 Tráfico de Drogas e Condutas Afins       0.98      0.98      0.98       400
#
#                                           accuracy                           0.77     17914
#                                          macro avg       0.76      0.77      0.76     17914
#                                       weighted avg       0.77      0.77      0.77     17914
#
# Matriz de confusão salva em: c:\Users\jonat\OneDrive\Área de Trabalho\classe-assunto\imgs\v1_original\matriz_confusao_linearsvc_assunto.png

# %%
le_assunto = joblib.load(r'..\..\models\v2_ftp\labels\label_encoder_assunto.joblib')
y_teste_assunto_enc = le_assunto.transform(y_teste_assunto)

# %%
modelo_lgbm_assunto = joblib.load(r'..\..\models\v2_ftp\modelo_lightgbm_assunto.joblib')
y_pred_lgbm_assunto_enc = modelo_lgbm_assunto.predict(X_teste_assunto)
y_pred_lgbm_assunto = le_assunto.inverse_transform(y_pred_lgbm_assunto_enc)

avaliar_modelo(modelo_lgbm_assunto, X_teste_assunto, y_teste_assunto_enc, "LightGBM Assunto")
registrar_metricas_assunto("LightGBM", y_teste_assunto, y_pred_lgbm_assunto)
# Out:
# ============================================================
# RELATÓRIO DE CLASSIFICAÇÃO - LIGHTGBM ASSUNTO
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87       400
#            1       0.78      0.83      0.81       400
#            2       0.94      0.93      0.94       400
#            3       0.84      0.93      0.89       400
#            4       0.79      0.73      0.76       400
#            5       0.93      0.94      0.94       400
#            6       0.72      0.77      0.75       400
#            7       0.66      0.73      0.69       400
#            8       0.75      0.71      0.73       400
#            9       0.82      0.90      0.86       400
#           10       0.78      0.76      0.77       400
#           11       0.49      0.50      0.49       400
#           12       0.52      0.58      0.55       400
#           13       0.69      0.62      0.65       400
#           14       0.85      0.75      0.80       400
#           15       0.82      0.84      0.83       400
#           16       0.97      0.94      0.96       400
#           17       0.97      0.96      0.97       400
#           18       0.57      0.58      0.57       400
#           19       0.84      0.83      0.84       400
#           20       0.68      0.77      0.72       400
#           21       0.99      0.93      0.96       400
#           22       0.75      0.61      0.67       237
#           23       0.89      0.88      0.88       400
#           24       0.91      0.81      0.86       400
#           25       0.82      0.75      0.78       400
#           26       0.79      0.87      0.83        98
#           27       0.74      0.83      0.79       242
#           28       0.84      0.60      0.70       137
#           29       0.75      0.71      0.73       200
#           30       0.30      0.29      0.29       200
#           31       0.83      0.86      0.85       400
#           32       0.82      0.79      0.81       400
#           33       0.97      0.97      0.97       400
#           34       0.87      0.93      0.90       600
#           35       0.59      0.59      0.59       600
#           36       0.53      0.51      0.52       400
#           37       0.57      0.46      0.51       400
#           38       0.95      0.95      0.95       400
#           39       0.95      0.98      0.96       400
#           40       0.72      0.72      0.72       400
#           41       0.95      0.96      0.96       400
#           42       0.61      0.61      0.61       400
#           43       0.66      0.61      0.64       400
#           44       0.55      0.60      0.57       400
#           45       0.76      0.79      0.77       400
#           46       0.98      0.97      0.97       400
#
#     accuracy                           0.78     17914
#    macro avg       0.77      0.77      0.77     17914
# weighted avg       0.78      0.78      0.78     17914
#
# Matriz de confusão salva em: c:\Users\jonat\OneDrive\Área de Trabalho\classe-assunto\imgs\v1_original\matriz_confusao_lightgbm_assunto.png

# %%
modelo_xgb_assunto = joblib.load(r'..\..\models\v2_ftp\modelo_xgboost_assunto.joblib')
y_pred_xgb_assunto_enc = modelo_xgb_assunto.predict(X_teste_assunto)
y_pred_xgb_assunto = le_assunto.inverse_transform(y_pred_xgb_assunto_enc)

avaliar_modelo(modelo_xgb_assunto, X_teste_assunto, y_teste_assunto_enc, "XGBoost Assunto")
registrar_metricas_assunto("XGBoost", y_teste_assunto, y_pred_xgb_assunto)
# Out:
# ============================================================
# RELATÓRIO DE CLASSIFICAÇÃO - XGBOOST ASSUNTO
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87       400
#            1       0.78      0.83      0.81       400
#            2       0.91      0.93      0.92       400
#            3       0.84      0.93      0.88       400
#            4       0.78      0.75      0.76       400
#            5       0.93      0.94      0.93       400
#            6       0.72      0.74      0.73       400
#            7       0.65      0.72      0.68       400
#            8       0.72      0.78      0.75       400
#            9       0.81      0.90      0.85       400
#           10       0.76      0.75      0.76       400
#           11       0.54      0.51      0.52       400
#           12       0.55      0.56      0.56       400
#           13       0.72      0.59      0.65       400
#           14       0.83      0.73      0.78       400
#           15       0.81      0.88      0.84       400
#           16       0.97      0.95      0.96       400
#           17       0.96      0.97      0.97       400
#           18       0.58      0.58      0.58       400
#           19       0.85      0.85      0.85       400
#           20       0.70      0.77      0.73       400
#           21       0.98      0.92      0.95       400
#           22       0.71      0.59      0.65       237
#           23       0.87      0.88      0.87       400
#           24       0.88      0.80      0.84       400
#           25       0.81      0.74      0.77       400
#           26       0.68      0.79      0.73        98
#           27       0.75      0.83      0.79       242
#           28       0.73      0.58      0.64       137
#           29       0.71      0.70      0.70       200
#           30       0.34      0.24      0.28       200
#           31       0.81      0.85      0.83       400
#           32       0.82      0.80      0.81       400
#           33       0.97      0.97      0.97       400
#           34       0.87      0.93      0.90       600
#           35       0.59      0.59      0.59       600
#           36       0.51      0.49      0.50       400
#           37       0.54      0.43      0.48       400
#           38       0.95      0.96      0.96       400
#           39       0.93      0.97      0.95       400
#           40       0.70      0.72      0.71       400
#           41       0.93      0.97      0.95       400
#           42       0.63      0.60      0.62       400
#           43       0.65      0.59      0.62       400
#           44       0.54      0.57      0.55       400
#           45       0.77      0.78      0.77       400
#           46       0.97      0.97      0.97       400
#
#     accuracy                           0.77     17914
#    macro avg       0.76      0.76      0.76     17914
# weighted avg       0.77      0.77      0.77     17914
#
# Matriz de confusão salva em: c:\Users\jonat\OneDrive\Área de Trabalho\classe-assunto\imgs\v1_original\matriz_confusao_xgboost_assunto.png

# %%
df_comparacao_assunto = pd.DataFrame(resultados_modelos_assunto)
display(df_comparacao_assunto.sort_values(by="F1-Score", ascending=False))
# Out:
#                 Modelo  Acurácia  F1-Score
# 4             LightGBM    0.7758    0.7751
# 3            LinearSVC    0.7746    0.7711
# 5              XGBoost    0.7728    0.7701
# 1        Random Forest    0.7760    0.7687
# 2  Regressão Logística    0.7676    0.7653
# 0          Naive Bayes    0.6646    0.6504
